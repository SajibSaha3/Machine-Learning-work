# %%
import pandas as pd

# %%
import numpy as np

# %%
from google.colab import drive #connet drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/MyDrive/shakil_vai/Heart Disease.csv") #load Dataset from drive

# %%
data.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
data.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
data.HeartDisease.value_counts()
# Out:
# No     292422
# Yes     27373
# Name: HeartDisease, dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  int64
#  6   MentalHealth      319795 non-null  int64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  int64
#  15  Asthma            319795 non-null  object
# ...

# %%
data.nunique() #Identify Unique value for encoding
# Out:
# HeartDisease           2
# BMI                 3604
# Smoking                2
# AlcoholDrinking        2
# Stroke                 2
# PhysicalHealth        31
# MentalHealth          31
# DiffWalking            2
# Sex                    2
# AgeCategory           13
# Race                   6
# Diabetic               4
# PhysicalActivity       2
# GenHealth              5
# SleepTime             24
# Asthma                 2
# KidneyDisease          2
# SkinCancer             2
# dtype: int64

# %%
data.Smoking.value_counts()
# Out:
# No     187887
# Yes    131908
# Name: Smoking, dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
 #en = ["HeartDisease","Smoking","AlcoholDrinking","Stroke","DiffWalking","Sex","AgeCategory","Race","Diabetic","PhysicalActivity","GenHealth","Asthma","KidneyDisease","SkinCancer"]

# %%
 import warnings
warnings.filterwarnings("ignore")
from pandas.core.dtypes.common import is_numeric_dtype

# %%
for x in data.columns:
    if is_numeric_dtype(data[x]):
        continue
    else:
        data[x] = le.fit_transform(data[[x]])
data.head(25)
# Out:
#     HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0              0  16.60        1                0       0               3
# 1              0  20.34        0                0       1               0
# 2              0  26.58        1                0       0              20
# 3              0  24.21        0                0       0               0
# 4              0  23.71        0                0       0              28
# 5              1  28.87        1                0       0               6
# 6              0  21.63        0                0       0              15
# 7              0  31.64        1                0       0               5
# 8              0  26.45        0                0       0               0
# 9              0  40.69        0                0       0               0
# 10             1  34.30        1                0       0              30
# 11             0  28.71        1                0       0               0
# ...

# %%
data2 = data.copy()
df3 = data.copy()
df4 = data.copy()
df5 = data.copy()
df6 = data.copy()
df7 = data.copy()

# %%
data2.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0               3
# 1             0  20.34        0                0       1               0
# 2             0  26.58        1                0       0              20
# 3             0  24.21        0                0       0               0
# 4             0  23.71        0                0       0              28
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0            30            0    0            7     5         2
# 1             0            0    0           12     5         0
# 2            30            0    1            9     5         2
# 3             0            0    0           11     5         0
# 4             0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
from sklearn.preprocessing import MinMaxScaler # Apply min max scaler for set value 1 and 2 of these class having unique number 2
m = MinMaxScaler() #feature_range=(0,1)

# %%
ms = m.fit(data2[['PhysicalHealth']]) # calculation everything

# %%
ms
# Out:
# MinMaxScaler()

# %%
data2[['PhysicalHealth']] = m.transform(data2[['PhysicalHealth']])

# %%
data2.head()
# Out:
#    HeartDisease    BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0             0  16.60        1                0       0        0.100000
# 1             0  20.34        0                0       1        0.000000
# 2             0  26.58        1                0       0        0.666667
# 3             0  24.21        0                0       0        0.000000
# 4             0  23.71        0                0       0        0.933333
#
#    MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0            30            0    0            7     5         2
# 1             0            0    0           12     5         0
# 2            30            0    1            9     5         2
# 3             0            0    0           11     5         0
# 4             0            1    0            4     5         0
#
#    PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
x= data2.drop('HeartDisease', axis=1) #Dependent and Independent variable seperation

# %%
y = data2[['HeartDisease']]

# %%
x.head()
# Out:
#      BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0  16.60        1                0       0        0.100000            30
# 1  20.34        0                0       1        0.000000             0
# 2  26.58        1                0       0        0.666667            30
# 3  24.21        0                0       0        0.000000             0
# 4  23.71        0                0       0        0.933333             0
#
#    DiffWalking  Sex  AgeCategory  Race  Diabetic  PhysicalActivity  GenHealth  \
# 0            0    0            7     5         2                 1          4
# 1            0    0           12     5         0                 1          4
# 2            0    1            9     5         2                 1          1
# 3            0    0           11     5         0                 0          2
# 4            1    0            4     5         0                 1          4
#
#    SleepTime  Asthma  KidneyDisease  SkinCancer
# ...

# %%
y.head()
# Out:
#    HeartDisease
# 0             0
# 1             0
# 2             0
# 3             0
# 4             0

# %%
# !pip install imblearn

# %%
y.value_counts()
# Out:
# HeartDisease
# 0               292422
# 1                27373
# dtype: int64

# %% [markdown]
# # **SMOTETomek**

# %%
from imblearn.combine import SMOTETomek #oversampling method applying
sm = SMOTETomek(random_state=42)
x,y= sm.fit_resample(x,y)

# %%
y.value_counts()
# Out:
# HeartDisease
# 0               290068
# 1               290068
# dtype: int64

# %%
from sklearn.model_selection import train_test_split # divided the dataset

# %%
xtrain,xtest,ytrain,ytest= train_test_split(x,y, test_size=.20, random_state=10)

# %%
xtrain.head()
# Out:
#               BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 418412  40.450000        0                0       0        0.000000
# 439749  25.321999        1                0       0        0.890567
# 313158  40.180000        0                0       0        0.233333
# 529191  29.911108        1                0       0        0.000000
# 303261  24.410000        0                0       0        0.000000
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 418412             0            0    1            9     5         0
# 439749            10            1    0           10     5         0
# 313158             0            0    0            4     3         0
# 529191             0            1    1           11     5         2
# 303261             0            0    1            9     5         0
#
#         PhysicalActivity  GenHealth  SleepTime  Asthma  KidneyDisease  \
# 418412                 0          4          8       0              0
# ...

# %%
ytrain.head()
# Out:
#         HeartDisease
# 418412             1
# 439749             1
# 313158             0
# 529191             1
# 303261             0

# %%
from sklearn.linear_model import LogisticRegression # Apply logidtic regression algorithm

# %%
logit = LogisticRegression()
logit
# Out:
# LogisticRegression()

# %%
logit.fit(xtrain,ytrain)
# Out:
# LogisticRegression()

# %%
pred = logit.predict(xtest)

# %%
logit.score(xtest,ytest)
# Out:
# 0.7377874306201951

# %%
logit.intercept_
# Out:
# array([-2.08737132])

# %%
logit.predict(x)
# Out:
# array([0, 1, 1, ..., 1, 0, 0])

# %%
logit.predict_proba(x)
# Out:
# array([[0.69885749, 0.30114251],
#        [0.34245662, 0.65754338],
#        [0.19619674, 0.80380326],
#        ...,
#        [0.28584296, 0.71415704],
#        [0.80504675, 0.19495325],
#        [0.62424252, 0.37575748]])

# %% [markdown]
# # **Under Sampling**
#
# > Indented block

# %%
from imblearn.under_sampling import NearMiss
NearMiss_obj = NearMiss()
new_x , new_y = NearMiss_obj.fit_resample(x,y)

# %%
new_x
# Out:
#               BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0       16.600000        1                0       0        0.100000
# 1       20.340000        0                0       1        0.000000
# 2       26.580000        1                0       0        0.666667
# 3       24.210000        0                0       0        0.000000
# 4       23.710000        0                0       0        0.933333
# ...           ...      ...              ...     ...             ...
# 580131  54.910000        1                1       0        0.966667
# 580132  81.550693        1                1       1        0.799543
# 580133  82.407748        1                1       1        0.918084
# 580134  82.887583        0                1       0        1.000000
# 580135  83.000000        1                1       1        1.000000
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                 30            0    0            7     5         2
# ...

# %%
new_x.shape
# Out:
# (580136, 17)

# %%
new_y
# Out:
#         HeartDisease
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 580131             1
# 580132             1
# 580133             1
# 580134             1
# 580135             1
#
# [580136 rows x 1 columns]

# %%
new_y.value_counts()
# Out:
# HeartDisease
# 0               290068
# 1               290068
# dtype: int64

# %%
new_xtrain,new_xtest,new_ytrain,new_ytest= train_test_split(new_x,new_y, test_size=.20, random_state=10)

# %%
logit.fit(new_xtrain,new_ytrain)
# Out:
# LogisticRegression()

# %%
pred = logit.predict(new_xtest)

# %%
logit.score(new_xtest,new_ytest)
# Out:
# 0.7406488089081946

# %% [markdown]
# # **Support Vector Machine**

# %%
from sklearn.svm import SVC #CLASSIFICATION

# %%
svm1 = SVC(kernel = 'linear')

# %%
new_xtrain
# Out:
#          BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 13262  30.18        0                0       0        0.000000             0
# 50796  40.77        1                0       1        0.466667            14
# 28451  36.18        1                0       0        0.666667            10
# 37469  36.02        1                0       0        0.000000             0
# 20162  25.96        0                0       0        0.333333             0
# ...      ...      ...              ...     ...             ...           ...
# 28017  23.40        1                0       0        0.000000             0
# 50496  25.79        1                0       1        1.000000            15
# 29199  27.89        1                0       0        0.833333             0
# 40061  31.09        0                0       1        0.133333             0
# 17673  31.75        0                0       0        0.000000             0
#
# ...

# %%
new_ytrain
# Out:
#        HeartDisease
# 13262             0
# 50796             1
# 28451             1
# 37469             1
# 20162             0
# ...             ...
# 28017             1
# 50496             1
# 29199             1
# 40061             1
# 17673             0
#
# [43796 rows x 1 columns]

# %%
svm1.fit(new_xtrain, new_ytrain)
# Out:
# SVC(kernel='linear')

# %%
svm1.score(new_xtest,new_ytest) #testing
# Out:
# 0.8542465753424657

# %% [markdown]
# # **KNN Classifier **

# %%
new_x
# Out:
#          BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0      25.10        0                0       0        0.000000             0
# 1      22.24        1                0       0        0.000000             0
# 2      26.63        0                0       0        0.000000             0
# 3      25.10        0                0       0        0.000000             0
# 4      26.63        0                0       0        0.000000             0
# ...      ...      ...              ...     ...             ...           ...
# 54741  38.45        0                0       1        1.000000            15
# 54742  36.21        1                0       0        0.000000             0
# 54743  37.12        1                0       0        0.000000             0
# 54744  33.20        1                0       0        0.000000             0
# 54745  27.41        1                0       0        0.233333             0
#
# ...

# %%
new_y
# Out:
#        HeartDisease
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 54741             1
# 54742             1
# 54743             1
# 54744             1
# 54745             1
#
# [54746 rows x 1 columns]

# %%
x
# Out:
#           BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  MentalHealth  \
# 0       16.60        1                0       0        0.100000            30
# 1       20.34        0                0       1        0.000000             0
# 2       26.58        1                0       0        0.666667            30
# 3       24.21        0                0       0        0.000000             0
# 4       23.71        0                0       0        0.933333             0
# ...       ...      ...              ...     ...             ...           ...
# 319790  27.41        1                0       0        0.233333             0
# 319791  29.84        1                0       0        0.000000             0
# 319792  24.24        0                0       0        0.000000             0
# 319793  32.81        0                0       0        0.000000             0
# 319794  46.56        0                0       0        0.000000             0
#
# ...

# %%
y
# Out:
#         HeartDisease
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 319790             1
# 319791             0
# 319792             0
# 319793             0
# 319794             0
#
# [319795 rows x 1 columns]

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
kc = KNeighborsClassifier(n_neighbors=20)

# %% [markdown]
# # **with Over Sampling **

# %%
kc.fit(xtrain,ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
kc.predict(xtest)
# Out:
# array([0, 0, 0, ..., 0, 0, 0])

# %%
kc.score(xtest,ytest) # BEST REsult
# Out:
# 0.9148673368876937

# %% [markdown]
# # **With Undersampling Data**

# %%
kc.fit(new_xtrain,new_ytrain)
# Out:
# KNeighborsClassifier(n_neighbors=20)

# %%
kc.score(new_xtest,new_ytest)
# Out:
# 0.8235616438356165

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
# from oversampling the divided data named into x and y and Undersampling it is new_x and new_y

# %%
clf = DecisionTreeClassifier()

# %%
clf.fit(xtrain,ytrain)
# Out:
# DecisionTreeClassifier()

# %% [markdown]
# # **With oversampling data**

# %%
clf.score(xtrain,ytrain)
# Out:
# 0.9977763796357745

# %%
clf.score(xtest,ytest)
# Out:
# 0.8869583204054193

# %%
x
# Out:
#               BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0       16.600000        1                0       0        0.100000
# 1       20.340000        0                0       1        0.000000
# 2       26.580000        1                0       0        0.666667
# 3       24.210000        0                0       0        0.000000
# 4       23.710000        0                0       0        0.933333
# ...           ...      ...              ...     ...             ...
# 580131  23.489151        0                0       0        0.000000
# 580132  28.764247        0                0       0        0.000000
# 580133  36.564192        0                0       0        0.670599
# 580134  22.338962        0                0       0        0.190947
# 580135  25.642594        0                0       0        0.004724
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                 30            0    0            7     5         2
# ...

# %%
y.value_counts()
# Out:
# HeartDisease
# 0               290068
# 1               290068
# dtype: int64

# %% [markdown]
# # **Undersampling data**

# %%
clf.fit(new_xtrain,new_ytrain)
# Out:
# DecisionTreeClassifier()

# %%
clf.score(new_xtrain,new_ytrain)
# Out:
# 0.9977526782559232

# %%
clf.score(new_xtest,new_ytest)
# Out:
# 0.8877426138518288

# %%
x
# Out:
#               BMI  Smoking  AlcoholDrinking  Stroke  PhysicalHealth  \
# 0       16.600000        1                0       0        0.100000
# 1       20.340000        0                0       1        0.000000
# 2       26.580000        1                0       0        0.666667
# 3       24.210000        0                0       0        0.000000
# 4       23.710000        0                0       0        0.933333
# ...           ...      ...              ...     ...             ...
# 580131  23.489151        0                0       0        0.000000
# 580132  28.764247        0                0       0        0.000000
# 580133  36.564192        0                0       0        0.670599
# 580134  22.338962        0                0       0        0.190947
# 580135  25.642594        0                0       0        0.004724
#
#         MentalHealth  DiffWalking  Sex  AgeCategory  Race  Diabetic  \
# 0                 30            0    0            7     5         2
# ...

# %%
y
# Out:
#         HeartDisease
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 580131             1
# 580132             1
# 580133             1
# 580134             1
# 580135             1
#
# [580136 rows x 1 columns]

# %% [markdown]
# # **Random forset**

# %% [markdown]
# # **Oversampling Data**

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rnd= RandomForestClassifier()
rnd
# Out:
# RandomForestClassifier()

# %%
rnd.fit(xtrain,ytrain)
# Out:
# RandomForestClassifier()

# %%
rnd.score(xtrain,ytrain)
# Out:
# 0.9977612969395054

# %%
rnd.score(xtest,ytest)
# Out:
# 0.9051866790774641

# %% [markdown]
# # **Under sampling data**

# %%
rnd.fit(new_xtrain,new_ytrain)
# Out:
# RandomForestClassifier()

# %%
rnd.score(new_xtrain,new_ytrain)
# Out:
# 0.9977397502305498

# %%
rnd.score(new_xtest,new_ytest)
# Out:
# 0.9059278794773675

# %% [markdown]
# # **XGBoost**

# %% [markdown]
# # **Over sampling**

# %%
from sklearn.model_selection import  GridSearchCV, RandomizedSearchCV
from sklearn.metrics import accuracy_score, classification_report
import seaborn as sns
import matplotlib.pyplot as plt

# %%
y.value_counts()
# Out:
# HeartDisease
# 0               290068
# 1               290068
# dtype: int64

# %%
sns.countplot(x='HeartDisease',data=y)
# Out:
# <Axes: xlabel='HeartDisease', ylabel='count'>

# %%
# Create the countplot
plt.figure(figsize=(4, 3))
ax = sns.countplot(x='HeartDisease', data=y, palette='Set2')

# Annotate the bars with their respective counts
for p in ax.patches:
    height = p.get_height()
    ax.annotate(f'{height}', (p.get_x() + p.get_width() / 2, height), ha='center', va='bottom', fontsize=12)

# Optionally, you can set the y-axis label
plt.ylabel('Count')

# Show the plot
plt.show()

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
GB = GradientBoostingClassifier (random_state= 40)

# %%
GB.fit (xtrain, ytrain)
# Out:
# GradientBoostingClassifier(random_state=40)

# %%
y_pred_GB = GB.predict(xtest)

# %%
y_pred_GB
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
print("GradientBoostingClassifier:")
print("Accuracy:", accuracy_score(ytest, y_pred_GB), '\n')
print("Classification Report:")
print(classification_report(ytest, y_pred_GB))
# Out:
# GradientBoostingClassifier:
# Accuracy: 0.7952821732685214
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.81      0.77      0.79     58149
#            1       0.78      0.82      0.80     57879
#
#     accuracy                           0.80    116028
#    macro avg       0.80      0.80      0.80    116028
# weighted avg       0.80      0.80      0.80    116028

# %% [markdown]
# # **Undersampling**

# %%
GB.fit (new_xtrain, new_ytrain)
# Out:
# GradientBoostingClassifier(random_state=40)

# %%
new_y_pred_GB = GB.predict(new_xtest)

# %%
print("GradientBoostingClassifier:")
print("Accuracy:", accuracy_score(new_ytest, new_y_pred_GB), '\n')
print("Classification Report:")
print(classification_report(new_ytest, new_y_pred_GB))
# Out:
# GradientBoostingClassifier:
# Accuracy: 0.7986520495052918
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.77      0.79     58107
#            1       0.78      0.83      0.80     57921
#
#     accuracy                           0.80    116028
#    macro avg       0.80      0.80      0.80    116028
# weighted avg       0.80      0.80      0.80    116028

# %% [markdown]
# # **AdaBoost** oversampling with grid search and parameter tuning

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
AD = AdaBoostClassifier(random_state= 60)

# %%
AD.fit (xtrain, ytrain)
# Out:
# AdaBoostClassifier(random_state=60)

# %%
y_pred_AD = AD.predict(xtest)

# %%
y_pred_AD
# Out:
# array([1, 1, 0, ..., 1, 0, 0])

# %%
print("AdaBoostClassifier:")
print("Accuracy:", accuracy_score(ytest, y_pred_AD), '\n')
print("Classification Report:")
print(classification_report(ytest, y_pred_AD))
# Out:
# AdaBoostClassifier:
# Accuracy: 0.771761988485538
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.76      0.77     58149
#            1       0.76      0.79      0.77     57879
#
#     accuracy                           0.77    116028
#    macro avg       0.77      0.77      0.77    116028
# weighted avg       0.77      0.77      0.77    116028

# %%
# Define hyperparameters for  Adaboost
AD_params = {
    'n_estimators' :[50,100,200],
    'learning_rate': [1.0,2.0,3.0],

}

# %%
# Perform Grid Search for Adaboost
AD_grid_search = GridSearchCV(estimator=AdaBoostClassifier (random_state=40),
                              param_grid=AD_params, cv=5)
AD_grid_search.fit(xtrain, ytrain)
# Out:
# GridSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=40),
#              param_grid={'learning_rate': [1.0, 2.0, 3.0],
#                          'n_estimators': [50, 100, 200]})

# %%
AD_grid_search.cv_results_
# Out:
# {'mean_fit_time': array([15.83392658, 33.13339615, 52.76818576, 12.81117287, 26.24967575,
#         51.68175478, 13.1145525 , 26.69643011, 51.55716252]),
#  'std_fit_time': array([1.76060209, 2.72877382, 2.34783068, 1.10046381, 1.06072975,
#         2.23865762, 1.45563768, 0.96482125, 1.48602167]),
#  'mean_score_time': array([0.54284449, 1.10735989, 2.06062007, 0.64054723, 0.90376329,
#         2.2494236 , 0.58536992, 0.95808835, 1.96444564]),
#  'std_score_time': array([0.09120165, 0.20256309, 0.37603214, 0.09936659, 0.04053659,
#         0.41166203, 0.05951291, 0.05742117, 0.31475913]),
#  'param_learning_rate': masked_array(data=[1.0, 1.0, 1.0, 2.0, 2.0, 2.0, 3.0, 3.0, 3.0],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_n_estimators': masked_array(data=[50, 100, 200, 50, 100, 200, 50, 100, 200],
# ...

# %%
tuning_result_AD_gs = pd.DataFrame(AD_grid_search.cv_results_)
tuning_result_AD_gs
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      15.833927      1.760602         0.542844        0.091202
# 1      33.133396      2.728774         1.107360        0.202563
# 2      52.768186      2.347831         2.060620        0.376032
# 3      12.811173      1.100464         0.640547        0.099367
# 4      26.249676      1.060730         0.903763        0.040537
# 5      51.681755      2.238658         2.249424        0.411662
# 6      13.114552      1.455638         0.585370        0.059513
# 7      26.696430      0.964821         0.958088        0.057421
# 8      51.557163      1.486022         1.964446        0.314759
#
#   param_learning_rate param_n_estimators  \
# 0                 1.0                 50
# 1                 1.0                100
# 2                 1.0                200
# 3                 2.0                 50
# 4                 2.0                100
# 5                 2.0                200
# ...

# %%
AD_grid_search.best_params_
# Out:
# {'learning_rate': 1.0, 'n_estimators': 200}

# %%
# AdaBoost and Grid Search
y_pred_AD_gs = AD_grid_search.predict(xtest)
print("\nDecision Tree Grid Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_AD_gs))
print("Classification Report:")
print(classification_report(ytest, y_pred_AD_gs))
# Out:
# Decision Tree Grid Search Performance:
# Accuracy: 0.7937308235943048
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79     58149
#            1       0.79      0.80      0.80     57879
#
#     accuracy                           0.79    116028
#    macro avg       0.79      0.79      0.79    116028
# weighted avg       0.79      0.79      0.79    116028

# %% [markdown]
# # **AdaBoost** oversampling with randomized search and parameter tuning

# %%
ad_params = {
    'n_estimators' :[50,100,200],
    'learning_rate': [1.0,2.0,3.0],

}

# %%
# Perform Randomized Search for Adaboost
ad_random_search = RandomizedSearchCV(estimator=AdaBoostClassifier(random_state=40),
                                      param_distributions=ad_params, n_iter=150, cv=5, random_state=40)
ad_random_search.fit(xtrain, ytrain)
# Out:
# RandomizedSearchCV(cv=5, estimator=AdaBoostClassifier(random_state=40),
#                    n_iter=150,
#                    param_distributions={'learning_rate': [1.0, 2.0, 3.0],
#                                         'n_estimators': [50, 100, 200]},
#                    random_state=40)

# %%
ad_random_search.cv_results_
# Out:
# {'mean_fit_time': array([13.63690748, 26.65067105, 50.11691742, 12.73219938, 27.76824908,
#         51.46275773, 13.47862515, 25.85189128, 52.52587929]),
#  'std_fit_time': array([0.54481444, 0.91224851, 0.52949306, 0.70947074, 0.76547741,
#         1.80455816, 0.51204865, 1.2095609 , 2.44304165]),
#  'mean_score_time': array([0.73381515, 0.99970379, 1.72491298, 0.56287184, 1.24193864,
#         1.95951953, 0.53604679, 0.9911705 , 2.0782402 ]),
#  'std_score_time': array([0.11833061, 0.15133364, 0.01797691, 0.11086649, 0.21794726,
#         0.30911679, 0.08657506, 0.16650111, 0.30711753]),
#  'param_n_estimators': masked_array(data=[50, 100, 200, 50, 100, 200, 50, 100, 200],
#               mask=[False, False, False, False, False, False, False, False,
#                     False],
#         fill_value='?',
#              dtype=object),
#  'param_learning_rate': masked_array(data=[1.0, 1.0, 1.0, 2.0, 2.0, 2.0, 3.0, 3.0, 3.0],
# ...

# %%
tuning_result_ad_rs = pd.DataFrame(ad_random_search.cv_results_)
tuning_result_ad_rs
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0      13.636907      0.544814         0.733815        0.118331
# 1      26.650671      0.912249         0.999704        0.151334
# 2      50.116917      0.529493         1.724913        0.017977
# 3      12.732199      0.709471         0.562872        0.110866
# 4      27.768249      0.765477         1.241939        0.217947
# 5      51.462758      1.804558         1.959520        0.309117
# 6      13.478625      0.512049         0.536047        0.086575
# 7      25.851891      1.209561         0.991171        0.166501
# 8      52.525879      2.443042         2.078240        0.307118
#
#   param_n_estimators param_learning_rate  \
# 0                 50                 1.0
# 1                100                 1.0
# 2                200                 1.0
# 3                 50                 2.0
# 4                100                 2.0
# 5                200                 2.0
# ...

# %%
ad_random_search.best_params_
# Out:
# {'n_estimators': 200, 'learning_rate': 1.0}

# %%
y_pred_ad_rs = ad_random_search.predict(xtest) #performance measure for each matrics
print("\n Decision Tree Randomized Search Performance:")
print("Accuracy:", accuracy_score(ytest, y_pred_ad_rs))
print("Classification Report:")
print(classification_report(ytest, y_pred_ad_rs))
# Out:
#  Decision Tree Randomized Search Performance:
# Accuracy: 0.7937308235943048
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.79      0.79     58149
#            1       0.79      0.80      0.80     57879
#
#     accuracy                           0.79    116028
#    macro avg       0.79      0.79      0.79    116028
# weighted avg       0.79      0.79      0.79    116028
