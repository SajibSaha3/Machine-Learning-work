# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# read the data set 
df = pd.read_csv("haberman.csv")
df.head()
# Out:
#    30  64   1  1.1
# 0  30  62   3    1
# 1  30  65   0    1
# 2  31  59   2    1
# 3  31  65   4    1
# 4  33  58  10    1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 305 entries, 0 to 304
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   30      305 non-null    int64
#  1   64      305 non-null    int64
#  2   1       305 non-null    int64
#  3   1.1     305 non-null    int64
# dtypes: int64(4)
# memory usage: 9.7 KB

# %% [markdown]
# # all the values of features are in integer format

# %%
# see the datatype of the columns name 
df.columns
# Out:
# Index(['30', '64', '1', '1.1'], dtype='object')

# %%
# rename columns with meaning full words
df.rename(columns={'30': 'age', '64': 'year', '1': "axil", "1.1": "survival"}, inplace=True)

# %%
#total number of features with roows 
df.shape
# Out:
# (305, 4)

# %% [markdown]
# # In this data set there is total number of 305 rows and 4 columns

# %%
#number ofn class
df['survival'].value_counts()
# Out:
# 1    224
# 2     81
# Name: survival, dtype: int64

# %% [markdown]
# # target column have "224" value in count for class "1" & "81" value for class "2"

# %%
# rename class type "yes" for 1 and "No" for 2
df['survival'].replace([1,2], ["yes","No"], inplace = True)
df
# Out:
#      age  year  axil survival
# 0     30    62     3      yes
# 1     30    65     0      yes
# 2     31    59     2      yes
# 3     31    65     4      yes
# 4     33    58    10      yes
# ..   ...   ...   ...      ...
# 300   75    62     1      yes
# 301   76    67     0      yes
# 302   77    65     3      yes
# 303   78    65     1       No
# 304   83    58     2       No
#
# [305 rows x 4 columns]

# %% [markdown]
# # replace class "1" with "yes" & class"2" with "No"

# %%
df['survival'].value_counts()
# Out:
# yes    224
# No      81
# Name: survival, dtype: int64

# %% [markdown]
# # class "yes" having values of count 224 indicated that patient are alive
# # class "No" having values of count 81 indicated that patient are no alive

# %%
df['survival'].unique()
# Out:
# array(['yes', 'No'], dtype=object)

# %% [markdown]
# # find unique class name for the target feature

# %%
print(df.groupby("survival").count())
# Out:
#           age  year  axil
# survival
# No         81    81    81
# yes       224   224   224

# %%
yes = df.loc[df["survival"]=="yes"]
no = df.loc[df["survival"]=="No"]

# %% [markdown]
# # store Class "yes" & "No" into variable yes and no

# %%
print(yes.describe())
# Out:
#               age        year        axil
# count  224.000000  224.000000  224.000000
# mean    52.116071   62.857143    2.799107
# std     10.937446    3.229231    5.882237
# min     30.000000   58.000000    0.000000
# 25%     43.000000   60.000000    0.000000
# 50%     52.000000   63.000000    0.000000
# 75%     60.000000   66.000000    3.000000
# max     77.000000   69.000000   46.000000

# %% [markdown]
# # Show statistical calculation for class "yes"

# %%
print(no.describe())
# Out:
#              age       year       axil
# count  81.000000  81.000000  81.000000
# mean   53.679012  62.827160   7.456790
# std    10.167137   3.342118   9.185654
# min    34.000000  58.000000   0.000000
# 25%    46.000000  59.000000   1.000000
# 50%    53.000000  63.000000   4.000000
# 75%    61.000000  65.000000  11.000000
# max    83.000000  69.000000  52.000000

# %% [markdown]
# # Show statistical calculation for class "no"

# %%
df
# Out:
#      age  year  axil survival
# 0     30    62     3      yes
# 1     30    65     0      yes
# 2     31    59     2      yes
# 3     31    65     4      yes
# 4     33    58    10      yes
# ..   ...   ...   ...      ...
# 300   75    62     1      yes
# 301   76    67     0      yes
# 302   77    65     3      yes
# 303   78    65     1       No
# 304   83    58     2       No
#
# [305 rows x 4 columns]

# %% [markdown]
# # objective

# %% [markdown]
# For predicting whether a patient will survive after 5 years or not based upon the patient's age, year of operation and the number of positive axillary nodes.

# %% [markdown]
# # boxPlot

# %%
sns.boxplot(x = "survival", y = "age", data  = df)
plt.show()

# %% [markdown]
# # ages above 78 will die within 5 years of operation but with ages 30 and below no one will die

# %%
sns.boxplot(x = "survival", y = "year", data  = df)
plt.show()

# %% [markdown]
# # ages 66 will alive more while ages ages with 60 and less die more

# %%
sns.boxplot(x = "survival", y = "axil", data  = df)
plt.show()

# %% [markdown]
# # Those who not alive the value of axil_nodes is higher for them rest of are outlayers

# %% [markdown]
# # violinplot

# %%
sns.violinplot(x = "survival", y = "axil", data  = df)
plt.show()

# %%
sns.violinplot(x = "survival", y = "year", data  = df)
plt.show()

# %%
sns.violinplot(x = "survival", y = "age", data  = df)
plt.show()

# %% [markdown]
# # scatter plot

# %%
df.plot(kind ="scatter", x="year", y = "age")
plt.show()

# %% [markdown]
# # does't carry any specific information at visualization

# %%
df.head()
# Out:
#    age  year  axil survival
# 0   30    62     3      yes
# 1   30    65     0      yes
# 2   31    59     2      yes
# 3   31    65     4      yes
# 4   33    58    10      yes

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival", height=4) \
   .map(plt.scatter, "age", "year") \
   .add_legend();

plt.show();

# %% [markdown]
# # # does't carry any specific information at visualization

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival", height=8) \
   .map(plt.scatter, "axil", "year") \
   .add_legend();

plt.show();

# %% [markdown]
# # # does't carry any specific information at visualization

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df, hue="survival", height=8) \
   .map(plt.scatter, "age", "year") \
   .add_legend();

plt.show();

# %% [markdown]
# # # does't carry any specific information at visualization

# %%
sns.set_style("whitegrid");
sns.pairplot(df,hue="survival",height=6)
plt.show()

# %% [markdown]
# # not understandable clearly because data are overlapped

# %%
sns.set_style("whitegrid");
sns.FacetGrid(df,hue="survival",height=6)\
    .map(sns.distplot,"age")\
    .add_legend();

plt.title('Histogram of ages of patients', fontsize=17)
plt.show();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # ages at middle it will overlapped more between live and die where people with lower age of high chance to alive and higer age have chance to die

# %%
sns.FacetGrid(df,hue="survival_status",height=6)\
    .map(sns.distplot,"operation_year")\
    .add_legend();

plt.title('Histogram of operation year of patients', fontsize=17)
plt.show();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # operation_year at 61-63 people die less than at year of 65

# %%
sns.FacetGrid(df,hue="survival",height=6)\
    .map(sns.distplot,"axil")\
    .add_legend();

plt.title('Histogram of auxillary nodes detected', fontsize=17)
plt.show();
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# # axil nodes having value 0 have more chances to alive respect to other

# %%
plt.figure(figsize=(20,6))
plt.subplot(131)
counts,bin_edges=np.histogram(yes["age"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,linewidth=3.0)
plt.plot(bin_edges[1:],cdf,linewidth=3.0)
plt.xlabel('AGE')
plt.ylabel("COUNT")
plt.title('PDF-CDF of AGE for Survival Status = YES')
plt.legend(['PDF-AGE', 'CDF-AGE'], loc = 5,prop={'size': 12})

plt.subplot(132)
counts,bin_edges=np.histogram(yes["year"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,linewidth=3.0)
plt.plot(bin_edges[1:],cdf,linewidth=3.0)
plt.xlabel('YEAR OF OPERATION')
plt.ylabel("COUNT")
plt.title('PDF-CDF of OPERATION YEAR for Survival Status = YES')
plt.legend(['PDF-OPERATION YEAR', 'CDF-OPERATION YEAR'], loc = 5,prop={'size': 11})

plt.subplot(133)
counts,bin_edges=np.histogram(yes["axil"],bins=10,density=True)
pdf=counts/sum(counts)
cdf=np.cumsum(pdf)
plt.plot(bin_edges[1:],pdf,linewidth=3.0)
plt.plot(bin_edges[1:],cdf,linewidth=3.0)
plt.xlabel('AUXILLARY NODES')
plt.ylabel("COUNT")
plt.title('PDF-CDF of AXIL NODES for Survival Status = YES')
plt.legend(['PDF-AXIL NODES', 'CDF-AXIL NODES'], loc = 5,prop={'size': 11})
plt.show()

# %%
sns.jointplot(x="age",y="year",data=df, kind="kde")
plt.show()

sns.jointplot(x="age",y="axil",data=df, kind="kde")
plt.show()

sns.jointplot(x="year",y="axil_nodes",data=df, kind="kde")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [32], in <cell line: 7>()
#       4 sns.jointplot(x="age",y="axil",data=df, kind="kde")
#       5 plt.show()
# ----> 7 sns.jointplot(x="year",y="axil_nodes",data=df, kind="kde")
#       8 plt.show()
#
# File ~\anaconda3\lib\site-packages\seaborn\_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# ...

# %%
df.head()
# Out:
#    age  year  axil survival
# 0   30    62     3      yes
# 1   30    65     0      yes
# 2   31    59     2      yes
# 3   31    65     4      yes
# 4   33    58    10      yes

# %%
df.columns
# Out:
# Index(['age', 'year', 'axil', 'survival'], dtype='object')

# %%
df['survival'].value_counts().plot(kind= "bar", color= 'g' ,figsize =(8,6))
plt.xlabel("number of survivals", labelpad = 8)
plt.ylabel("survival_count", labelpad = 8)
plt.title("Survival Status", y = 1.02)
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# # after 5 years of operation people alive more than dead

# %%
df['survival'].value_counts().plot(kind= "pie",autopct = '%1.2f%%', shadow= True, startangle = 90, explode = (.3,0))
plt.title("pie Chart Demo")
plt.show()

# %% [markdown]
# # percentage of alive people after operation was 73.44% which was quite high repect to dead
