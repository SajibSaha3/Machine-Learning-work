# %% [markdown]
# # What is Dataset Imbalance
#
# ![image.png](attachment:0bf76e1b-65ab-49bd-a4ed-afd60aa6c2e7.png)

# %% [markdown]
# Imbalance data mainly observed in this kind of situation where the classification related problems are aant to be solved. It mainly refers the situation where the amount of data for per class are not equal to each other or their is a huge difference in datapoint for per class. In this situation a particular class contain more data significantly than others which can be explained by the term of Skewness.
#
# ![image.png](attachment:dc79334b-09c6-44de-8d51-69f7de9b9e84.png)
#
# by the help of the skewness of data distribution we able to find out the data distribution visually for each class where it is more easy for us to find the majority and minority class having datapoints.

# %% [markdown]
# # **Problem with Imbalance Dataset**

# %% [markdown]
# Imbalance dataset become a major issue for machine learning algorithmns beacuse they become baised at the time of training with the majority class where as perform more poorly for the minority class.  This reasons will casued for the model that it would be classified the unseen data related to the majority class but not enough trained to classify the minority class and most often fail to classify them. So this problem of imbalance dataset may often leads to both overfitting and underfitting problem  and it merely depends on how we handle this kind of dataset.
#
# ![image.png](attachment:f0327b03-700b-4ca4-a114-c7e36b906369.png)
#
# these are some most common problem we have faced for the imbalance dataset.
# When a model is trained with the imbalance dataset the model become baised respect to the majority class. For this consiquences the minority class will be struggled to correctly classified and this often falid to classity the minority class which leads a situation where majority class are highly classified and minority are poorly. This mainly happen when the unseen or new data is passed belonging the minority class to classify. This problem in is called inefficient learning based on the training data. Overall this problem mainly affect the total evaluation process.

# %% [markdown]
# # Issues with Oversampling and Undersampling
#
# ![image.png](attachment:f10dfecb-6220-4d61-a382-ab220298077f.png)

# %% [markdown]
# # Oversampling
#
# When oversampling technique is takes place their might be a possibility of overfitting problem specially takes place for the minority class, since the synthetic data are produced by coping the actual data points. Also generating new samples increases the dataset with more datapoints which leads a extra computational power and introduced more complexity at the train state. The most considering issue is that when the synthetic data is generating form ture samples there might be a issue of information loss if the synthetic samples doesn't represents the actual samples properly.
#
# ![image.png](attachment:d93080b2-ce97-4b7a-9c07-6d69e719900b.png)
#
# # Undersampling
#
# By removing datapoint from the majority class may often faced an issue of loss of valuable information because a huge number of datapoints as removing from the dataset. As the data points are sampling respect to the minority class so the model will work more sensitively for the minority class this will create an issue with the majority class where model will perform with it poorly thus the model will be baised. The Robustness  Model is reduced because for lossing the important information for majority class it will not performing as required for the unknown and unseen data points which actually belongs to the majority class.

# %% [markdown]
# # Resolving Issues
#
# ![image.png](attachment:0b05b54e-00d1-480a-8acb-a8110a9ad714.png)

# %% [markdown]
# To resolve the following issues at first we have to carefully findout the characteristics of the dataset and needs to select the appropriate techniques of oversampling and undersampling which will be fitted for that dataset. Using techniques like cross-validation. Using techniques like cross-validation and monitoring model performance on validation or test data can help assess the effectiveness of the sampling strategy and identify potential issues such as overfitting or bias.

# %% [markdown]
# # Cross_validation
#
# ![image.png](attachment:b63a7ab0-b482-406e-920f-db6b458eefaa.png)

# %% [markdown]
# Cross-validation is a type resampling procedure used to evaluate machine learning models on a limited data sample. It is a technique used to protect against overfitting in a predictive model, particularly in a case where the amount of data may be limited.
#
# # Types of Cross Validation
# ![image.png](attachment:be3d46f0-674e-4575-a717-effabaf2d656.png)

# %% [markdown]
# # K-Fold Cross Validation
#
# ![image.png](attachment:36145ae1-c43c-4d0e-a2d6-eb10ba89a4bd.png)
#
# In K_Fold Cross Validation the performance and generalization ability of a model is assessed. K_Fold Cross Validation technique is more useful when we are dealing with limited datapoints, where the data original dataset is divided into K number of subsets or folds and each folds containing the same amount of data points as well.Each fold is used as a testing set exactly once, while the remaining k-1 folds are used as training data.For the each unique group of k-fold a group is taken as hold out or test set where the remaining groups are considered as training set. Then it fit the model on the training set and evaluate it on the test set and retain the evaluation score and discard
# the model.
#
# The performance of the model is calculated based on the following methods:
#
# ![image.png](attachment:c96e3fae-b4a1-4627-bdf9-aed942996fc5.png)
#
# However, the common choices for k in k-fold cross-validation are 5, 10, or even higher values, depending on the size of the dataset and computational resources available. However, smaller values of k may result in higher variance in the performance estimate, while larger values may increase the computational cost.

# %% [markdown]
# # Stratified Cross Validation
#
# Stratified k-fold cross-validation is geneal variation for the  k-fold cross-validation aims to focused specially these class having imbalance class in a dataset. In Stratified k-fold technique the class distribution will be same as like as the original dataset. In this technique the datasets are divided as just like the traditional k-fold cross-validation. In Stratified Cross Validation the data distribution is preserved that means if the provided dataset is imbalanced then all the fold will also have the similar amount of imbalance ratio as like the original dataset. The training as testing stages are performing as like the traditional k-fold cross-validation technique.
#
# ![image.png](attachment:0fc036e6-0c3b-44a9-8854-a7bdea2f6c60.png)

# %% [markdown]
# # Leave-One-Out Cross-Validation (LOOCV)
#
#
# Leave-One-Out Cross-Validation (LOOCV) is another type of a special case of k-fold cross-validation where k is equal to the number of datapoint presents into the dataset.  In this approach a model is trained over the all the other datapoints expect one. That datapoints is used a test point. After testing over the single datapoint the performance are then avaraged across all datapoints for obtaining a single test result for the proposed model.
#
# ![image.png](attachment:39cffb2d-0d5b-4007-98a4-e539c74dc9e4.png)
#
#
# There is some advantages to work the Leave-One-Out Cross-Validation (LOOCV) these are
# **High Utilization of Data and Low Bias**
# beacuse in  Leave-One-Out Cross-Validation we makes the maximum use of the available data we have for both training and testing peocess, since we olny use one datapoint to test and use all the other datapoints in training phase.
#
# Although it has some advantages but there is also be some disadvantages regarding uses of the  Leave-One-Out Cross-Validation and these are
# **High Variance and Computational Cost**
# Leave-One-Out Cross-Validation is introduced us with a large Computational Cost when we are dealing with a large amonut of data, since the training and testing process is repeated for all the single datapoints seperately.
#
# However this apporoach can be useful for us if we are dealing with a moderate and small dataset and wish to have an unbaised model performance.
